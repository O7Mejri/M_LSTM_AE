# %%
# %cd /content/drive/MyDrive/ColabNotebooks/PROGS/M_LSTM_AE
# Out:
# /content/drive/MyDrive/ColabNotebooks/PROGS/M_LSTM_AE

# %%
# !pip install PyGithub
from github import Github
import os
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.9/302.9 kB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 856.7/856.7 kB 10.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyjwt
#     Found existing installation: PyJWT 2.3.0
#     Uninstalling PyJWT-2.3.0:
#       Successfully uninstalled PyJWT-2.3.0
# ...

# %%
# !git config --global user.email "oussama.mejri@enis.tn"
# !git config --global user.name "O7Mejri"

token = "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"
email = "oussama.mejri@enis.tn"
username = "O7Mejri"

url = f'https://{token}@github.com/{username}/M_LSTM_AE.git'

# !git remote set-url origin {url}

# %%
# !echo "# M_LSTM_AE" >> README.md
# !git init
# !git add README.md
# !git commit -m "first commit"
# !git branch -M main
# !git push -u origin main
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/ColabNotebooks/PROGS/M_LSTM_AE/.git/
# [main 0d6a784] first commit
#  1 file changed, 1 insertion(+)
# Enumerating objects: 5, done.
# Counting objects: 100% (5/5), done.
# Writing objects: 100% (3/3), 255 bytes | 63.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/O7Mejri/M_LSTM_AE.git
#    aae294d..0d6a784  main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.

# %%
# !git add .
